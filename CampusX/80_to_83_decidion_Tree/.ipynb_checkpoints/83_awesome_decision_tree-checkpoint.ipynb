# %%
# !pip install dtreeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dtreeviz in c:\users\vaish\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (2.2.1)
# Requirement already satisfied: scikit-learn in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (3.9.2)
# Requirement already satisfied: colour in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\vaish\appdata\roaming\python\python312\site-packages (from dtreeviz) (8.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: colorama in c:\users\vaish\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\vaish\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from scikit-learn->dtreeviz) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\vaish\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from dtreeviz.trees import dtreeviz
from IPython.display import Image, display_svg, SVG
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 3
#       1 from sklearn.datasets import *
#       2 from dtreeviz.trees import *
# ----> 3 from dtreeviz.trees import dtreeviz
#       4 from IPython.display import Image, display_svg, SVG
#
# ImportError: cannot import name 'dtreeviz' from 'dtreeviz.trees' (C:\Users\vaish\AppData\Roaming\Python\Python312\site-packages\dtreeviz\trees.py)

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 1. Classification

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                feature_names=iris.feature_names,
#       5                class_names=["setosa", "versicolor", "virginica"])
#       6 viz
#
# NameError: name 'dtreeviz' is not defined

# %% [markdown]
# # 2. Regression

# %%
regr = tree.DecisionTreeRegressor(max_depth=1)
boston = load_boston()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz(regr,
               X_train,
               y_train,
               target_name='price',
               feature_names=boston.feature_names,
               scale=2
              )
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 regr = tree.DecisionTreeRegressor(max_depth=1)
# ----> 2 boston = load_boston()
#       4 X_train = boston.data
#       5 y_train = boston.target
#
# NameError: name 'load_boston' is not defined
