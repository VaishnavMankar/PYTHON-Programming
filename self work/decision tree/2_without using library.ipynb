# %%
# Load the dataset
data = []
with open('cleandataPune.csv', 'r') as file:
    for line in file.readlines()[1:]:  # Skip header
        fields = line.strip().split(',')
        data.append([float(fields[1]), float(fields[2]), float(fields[3]), fields[4], int(fields[5])])  # total_sqft, bath, price, site_location, bhk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 for line in file.readlines()[1:]:  # Skip header
#       5     fields = line.strip().split(',')
# ----> 6     data.append([float(fields[1]), float(fields[2]), float(fields[3]), fields[4], int(fields[5])])  # total_sqft, bath, price, site_location, bhk
#
# ValueError: could not convert string to float: ''
