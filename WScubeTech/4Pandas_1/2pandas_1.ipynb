# %%
#Habeling Duplicate Valus in Pandas

# %%
import pandas as pd

data = pd.read_csv("E:/Scientific computing/project/company1.csv")
print(data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
print(data["EEID"].duplicated().sum())
# Out:
# 2

# %%
print(data.duplicated("EEID").sum())
# Out:
# 2

# %%
 print(data.drop_duplicates("EEID"))
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN

# %%
 print(data["EEID"].drop_duplicates())
# Out:
# 0    EMP01
# 1    EMP02
# 2    EMP03
# 4    EMP05
# 5    EMP06
# Name: EEID, dtype: object
